# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Cage6666/Big-Data-Application/blob/master/1-Python%20Crash%20Course/Python%20Crash%20Course.ipynb)

# %% [markdown]
# # Python速成小课堂

# %% [markdown]
# ### Jupyter Notebook使用初步
# 这个Notebook旨在向大家介绍Python和Jupyter Notebook的一些基础功能与实现。
# 首先，Jupyter Notebook是一个基于浏览器的编程环境，因为拥有非常出色的交互和展示效果而在数据科学领域使用频繁。更多的信息和相关项目可以在他们的主页找到[Jupyter project page](http://jupyter.org)
# 每一个可执行的单元格叫作Cell，他们可以写入Python代码或是Markdown语言，比如你在读的这个Cell就是典型的Markdown Cell,你可以双击看它是如何写成的。想要执行一个单元格，可以点击 &#9654;按钮，或者使用Shift+Enter（执行此单元格并进入下一个单元格），Control+Enter（执行并停留在此单元格）。除此之外，很好用的快捷键还有b（在下方插入单元格），a（在上方插入单元格），m（把单元格转为Markdown），y（把单元格转为Code），z（恢复之前误删的单元格）。
# 接下来，我们进入Python语言部分，了解一些基础的Python用法与特性。

# %% [markdown]
# ### 基本运算和输出语句

# %%
1+1
# Out:
# 2

# %%
a = 1.0
b = 2.0

# %%
print(a)
b
# Out:
# 1.0
# 2.0

# %%
c = "sum"
print("The "+c+" of "+ str(a) +" is 2.")
# Out:
# The sum of 1.0 is 2.

# %% [markdown]
# ### 列表
# Python中的列表(List)是指方括号中的数据类型。
# 列表是Python中最基本的数据结构。列表中的每个元素都分配一个索引，第一个的索引是0，第二个的索引是1，依此类推。可以使用for语句来实现其中的循环。

# %%
list1 = ["a", "b", "c", "d"]
list2 = [1, 2, 3, "4", [1,2]]

# %%
print(list1[0])
print(list1[-1])
print(list1[1:2])
print(list1[0:4:2])
for a in list1:
    print(a)
# Out:
# a
# d
# ['b']
# ['a', 'c']
# a
# b
# c
# d

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
lst[3][1][2][0]
# Out:
# 'hello'

# %% [markdown]
# ### 字典
# 字典是另一种可变容器模型，在数据科学中是一个非常常用的数据类型，且可存储任意类型对象。
# 字典中的值是key->value组成一对，用冒号分割，每个键值对之间用逗号分割，整个字典包括在花括号{}中,格式如下所示：

# %%
dict1 = {"a":1, "b":2, "c":3}

# %%
dict1["a"]
# Out:
# 1

# %%
{i:i**2 for i in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# ### if,if else

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')
# Out:
# middle

# %% [markdown]
# ### for loop 循环

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for jelly in seq:
    print(jelly+jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### 函数

# %%
def square(x):
    return x**2

# %%
out = square(2)
print(out)
# Out:
# 4

# %%
def domainGet(email):
    return email.split('@')[-1]

# %%
domainGet('user@domain.com')
# Out:
# 'domain.com'
